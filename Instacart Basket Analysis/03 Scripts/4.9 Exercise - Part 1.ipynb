# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\Günay\Documents\Instacart Basket Analysis'

# %%
customers=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col=False)

# %%
customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# ## Step-4. Data Wrangling

# %%
customers.rename(columns={'STATE':'state'},inplace=True)

# %%
customers.rename(columns={'First Name':'first_name'}, inplace=True)

# %%
customers.rename(columns={'Age':'age'}, inplace=True)

# %%
customers.rename(columns={'Gender':'gender'}, inplace=True)

# %%
customers.rename(columns={'Surname':'surname'}, inplace=True)

# %%
customers.head()
# Out:
#    user_id first_name    Surnam  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customers.describe()
# Out:
#              user_id            age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
customers.shape
# Out:
# (206209, 10)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   first_name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   gender        206209 non-null  object
#  4   state         206209 non-null  object
#  5   age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# ## Step-5. Consistency Check

# %%
customers.isnull().sum()
# Out:
# user_id             0
# first_name      11259
# Surnam              0
# gender              0
# state               0
# age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
customers_nan=customers[customers['first_name'].isnull()==True]

# %%
customers_nan
# Out:
#         user_id first_name    Surnam  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         n_dependants fam_status  income
# ...

# %%
customers_dups=customers[customers.duplicated()]

# %%
customers_dups
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, Surnam, gender, state, age, date_joined, n_dependants, fam_status, income]
# Index: []

# %% [markdown]
# ## Step-6. Combining data

# %%
orders_products=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged3.pkl'))

# %%
orders_products
# Out:
#           order_id  user_id eval_set  order_number  order_dow  order_time  \
# 0        1501582.0      2.0    prior           2.0        5.0        10.0
# 1         382106.0    235.0    prior           2.0        6.0         8.0
# 2        1264640.0    235.0    prior           8.0        3.0         2.0
# 3         909400.0    235.0    prior          20.0        5.0        10.0
# 4        1698838.0    352.0    prior           9.0        0.0        15.0
# ...            ...      ...      ...           ...        ...         ...
# 1993212        NaN      NaN      NaN           NaN        NaN         NaN
# 1993213        NaN      NaN      NaN           NaN        NaN         NaN
# 1993214        NaN      NaN      NaN           NaN        NaN         NaN
# 1993215        NaN      NaN      NaN           NaN        NaN         NaN
# 1993216        NaN      NaN      NaN           NaN        NaN         NaN
#
#          days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
# To check the datatypes

# %%
orders_products.dtypes
# Out:
# order_id                   float64
# user_id                    float64
# eval_set                    object
# order_number               float64
# order_dow                  float64
# order_time                 float64
# days_since_prior_order     float64
# product_id                   int64
# add_to_cart_order          float64
# reordered                  float64
# split                      float64
# _merge                    category
# product_name                object
# aisle_id                   float64
# department_id              float64
# prices                     float64
# exists                    category
# price_range                 object
# price_range_loc             object
# busiest_day                 object
# busiest_days                object
# busiest_period_of_day       object
# max_order                  float64
# loyalty_flag                object
# mean_price                 float64
# spending_flag               object
# days_median                float64
# ...

# %%
customers.dtypes
# Out:
# user_id          int64
# first_name      object
# Surnam          object
# gender          object
# state           object
# age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
# To change the datatype of user_id

# %%
orders_products['user_id']=orders_products['user_id'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-0c1f3e71d089> in <module>
# ----> 1 orders_products['user_id']=orders_products['user_id'].astype('int64')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
# ...

# %%
customers['user_id']=customers['user_id'].astype('float64')

# %%
customers.dtypes
# Out:
# user_id         float64
# first_name       object
# Surnam           object
# gender           object
# state            object
# age               int64
# date_joined      object
# n_dependants      int64
# fam_status       object
# income            int64
# dtype: object

# %%
# To merge the dataframes

# %%
pd.merge(orders_products, customers, on=['user_id'], how='outer')
# Out:
#           order_id   user_id eval_set  order_number  order_dow  order_time  \
# 0        1501582.0       2.0    prior           2.0        5.0        10.0
# 1        1501582.0       2.0    prior           2.0        5.0        10.0
# 2        1501582.0       2.0    prior           2.0        5.0        10.0
# 3        1901567.0       2.0    prior           3.0        1.0        10.0
# 4        1901567.0       2.0    prior           3.0        1.0        10.0
# ...            ...       ...      ...           ...        ...         ...
# 2133594        NaN  122741.0      NaN           NaN        NaN         NaN
# 2133595        NaN  168073.0      NaN           NaN        NaN         NaN
# 2133596        NaN  135902.0      NaN           NaN        NaN         NaN
# 2133597        NaN   81095.0      NaN           NaN        NaN         NaN
# 2133598        NaN   80148.0      NaN           NaN        NaN         NaN
#
# ...

# %%
ord_prods_cust_merged=pd.merge(orders_products, customers, on=['user_id'], how='outer')

# %%
ord_prods_cust_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ord_prods_cust_merged.pkl'))
