# %% [markdown]
# # Step-1

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\Günay\Documents\Instacart Basket Analysis'

# %%
df_ords_prods_merged=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged2.pkl'))

# %%
df_ords_prods_merged.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_time  \
# 0  1501582.0      2.0    prior           2.0        5.0        10.0
# 1   382106.0    235.0    prior           2.0        6.0         8.0
# 2  1264640.0    235.0    prior           8.0        3.0         2.0
# 3   909400.0    235.0    prior          20.0        5.0        10.0
# 4  1698838.0    352.0    prior           9.0        0.0        15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                    10.0        8479                3.0        0.0  ...
# 1                    13.0        8479                3.0        1.0  ...
# 2                    17.0        8479               10.0        1.0  ...
# 3                    25.0        8479                7.0        1.0  ...
# 4                    16.0        8479               13.0        1.0  ...
#
#                             product_name aisle_id department_id  prices  \
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (1993217, 22)

# %% [markdown]
# # Step-2

# %%
df_ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              16.459188
# 2.0              17.506440
# 3.0              18.387829
# 4.0              18.848129
# 5.0              16.129429
# 6.0              17.618832
# 7.0              18.426678
# 8.0              15.993656
# 9.0              17.073445
# 10.0             21.032967
# 11.0             17.465383
# 12.0             16.957199
# 13.0             17.813777
# 14.0             17.980317
# 15.0             17.317769
# 16.0             18.764976
# 17.0             17.035425
# 18.0             20.714286
# 19.0             18.314142
# 20.0             17.432502
# 21.0             23.125907

# %% [markdown]
# # Step-3

# %%
# The subset has 1000000 rows, but the entire dataframe has 1993217 rows. 
# There is not a big changing between the means of order numbers at the subset and the entire dataframe. 
# I think, the reason is that there is not any sorting at the entire dataframe, it`s quite random.
# That`s why, the subset which includes the first 1000000 rows was also random and the means didn`t change so much.

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  order_time  \
# 0        1501582.0      2.0    prior           2.0        5.0        10.0
# 1         382106.0    235.0    prior           2.0        6.0         8.0
# 2        1264640.0    235.0    prior           8.0        3.0         2.0
# 3         909400.0    235.0    prior          20.0        5.0        10.0
# 4        1698838.0    352.0    prior           9.0        0.0        15.0
# ...            ...      ...      ...           ...        ...         ...
# 1993212        NaN      NaN      NaN           NaN        NaN         NaN
# 1993213        NaN      NaN      NaN           NaN        NaN         NaN
# 1993214        NaN      NaN      NaN           NaN        NaN         NaN
# 1993215        NaN      NaN      NaN           NaN        NaN         NaN
# 1993216        NaN      NaN      NaN           NaN        NaN         NaN
#
#          days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# # Step-4

# %%
df_ords_prods_merged['max_order'] = df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  order_time  \
# 0        1501582.0      2.0    prior           2.0        5.0        10.0
# 1         382106.0    235.0    prior           2.0        6.0         8.0
# 2        1264640.0    235.0    prior           8.0        3.0         2.0
# 3         909400.0    235.0    prior          20.0        5.0        10.0
# 4        1698838.0    352.0    prior           9.0        0.0        15.0
# ...            ...      ...      ...           ...        ...         ...
# 1993212        NaN      NaN      NaN           NaN        NaN         NaN
# 1993213        NaN      NaN      NaN           NaN        NaN         NaN
# 1993214        NaN      NaN      NaN           NaN        NaN         NaN
# 1993215        NaN      NaN      NaN           NaN        NaN         NaN
# 1993216        NaN      NaN      NaN           NaN        NaN         NaN
#
#          days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['max_order'] <= 40) & (df_ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merged['loyalty_flag'].value_counts(dropna=False)
# Out:
# Regular customer    983245
# Loyal customer      657915
# New customer        341938
# NaN                  10119
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # Step-5

# %%
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer     9.755425
# New customer      12.234317
# Regular customer  11.396142

# %%
# Loyal customers mostly purchase the cheapest products.

# %% [markdown]
# # Step-6

# %%
df_ords_prods_merged['mean_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  order_time  \
# 0        1501582.0      2.0    prior           2.0        5.0        10.0
# 1         382106.0    235.0    prior           2.0        6.0         8.0
# 2        1264640.0    235.0    prior           8.0        3.0         2.0
# 3         909400.0    235.0    prior          20.0        5.0        10.0
# 4        1698838.0    352.0    prior           9.0        0.0        15.0
# ...            ...      ...      ...           ...        ...         ...
# 1993212        NaN      NaN      NaN           NaN        NaN         NaN
# 1993213        NaN      NaN      NaN           NaN        NaN         NaN
# 1993214        NaN      NaN      NaN           NaN        NaN         NaN
# 1993215        NaN      NaN      NaN           NaN        NaN         NaN
# 1993216        NaN      NaN      NaN           NaN        NaN         NaN
#
#          days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['mean_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['mean_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merged['spending_flag'].value_counts(dropna=False)
# Out:
# Low spender     1932708
# High spender      50389
# NaN               10120
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Step-7

# %%
df_ords_prods_merged['days_median'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  order_time  \
# 0        1501582.0      2.0    prior           2.0        5.0        10.0
# 1         382106.0    235.0    prior           2.0        6.0         8.0
# 2        1264640.0    235.0    prior           8.0        3.0         2.0
# 3         909400.0    235.0    prior          20.0        5.0        10.0
# 4        1698838.0    352.0    prior           9.0        0.0        15.0
# ...            ...      ...      ...           ...        ...         ...
# 1993212        NaN      NaN      NaN           NaN        NaN         NaN
# 1993213        NaN      NaN      NaN           NaN        NaN         NaN
# 1993214        NaN      NaN      NaN           NaN        NaN         NaN
# 1993215        NaN      NaN      NaN           NaN        NaN         NaN
# 1993216        NaN      NaN      NaN           NaN        NaN         NaN
#
#          days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['days_median'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['days_median'] <= 20) & (df_ords_prods_merged['days_median'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['days_median'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merged['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        1345256
# Regular customer          431606
# Non-frequent customer     206236
# NaN                        10119
# Name: frequency_flag, dtype: int64

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged3.pkl'))
